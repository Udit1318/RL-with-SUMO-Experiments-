# %%
import traci
import random
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict


def analyze_random_actions(environment, episodes=5, total_sim_time=3600, action_duration=80):
    """
    Select random actions, apply them for fixed duration, and analyze flow ratios.
    
    Parameters:
        environment: The traffic environment
        episodes: Number of simulation episodes to run
        total_sim_time: Total simulation time per episode (seconds)
        action_duration: Duration to apply each action (seconds)
    """
    # Storage for collected data
    all_flow_ratios = []
    all_actions = []
    all_waiting_times = []
    
    print("\nRandom Action Analysis")
    print("Format: Episode | Action | Flow Ratios | Avg Wait Time")
    print("-" * 75)
    
    for episode in range(episodes):
        # Start the simulation
        environment.start_simulation()
        
        # Data for this episode
        episode_flow_ratios = []
        episode_actions = []
        episode_waiting_times = []
        
        # Track vehicles for metrics
        total_waiting_time = 0.0
        vehicle_counts = set()
        
        # Run simulation steps
        step = 0
        while step < total_sim_time:
            # Select random action
            action = random.choice(list(environment.action_space.keys()))
            episode_actions.append(action)
            
            # Apply the action
            green_durations = environment.action_space[action]
            environment.update_traffic_light_program("J1", green_durations)
            
            # Record initial vehicle counts for flow tracking
            controlled_lanes = traci.trafficlight.getControlledLanes("J1")
            initial_vehicles = {lane: set(traci.lane.getLastStepVehicleIDs(lane)) for lane in controlled_lanes}
            
            # Group lanes by phase (assuming 3 lanes per phase based on your setup)
            phase_lanes = [
                controlled_lanes[0:3],   # Lanes for first phase
                controlled_lanes[3:6],   # Lanes for second phase
                controlled_lanes[6:9],   # Lanes for third phase
                controlled_lanes[9:12]   # Lanes for fourth phase
            ]
            
            # Run simulation steps for the action duration
            action_waiting_time = 0
            for _ in range(action_duration):
                traci.simulationStep()
                
                # Update metrics
                current_wait = sum(environment.compute_waiting_time().values())
                action_waiting_time += current_wait
                total_waiting_time += current_wait
                
                # Track vehicles
                current_vehicles = set(traci.vehicle.getIDList())
                vehicle_counts.update(current_vehicles)
            
            # Calculate average waiting time for this action
            avg_action_wait = action_waiting_time / action_duration
            episode_waiting_times.append(avg_action_wait)
            
            # Calculate flow ratios for each phase
            phase_flow_ratios = []
            
            for phase_idx, lanes in enumerate(phase_lanes):
                phase_in = 0
                phase_out = 0
                
                for lane in lanes:
                    # Get final vehicle set
                    final_vehicles = set(traci.lane.getLastStepVehicleIDs(lane))
                    
                    # Calculate inflow (vehicles in final set that weren't in initial set)
                    inflow = len(final_vehicles - initial_vehicles[lane])
                    
                    # Calculate outflow (vehicles in initial set that aren't in final set)
                    outflow = len(initial_vehicles[lane] - final_vehicles)
                    
                    phase_in += inflow
                    phase_out += outflow
                
                # Calculate flow ratio with epsilon to avoid division by zero
                epsilon = 1e-6
                if phase_in + epsilon > 0:
                    ratio = phase_out / (phase_in + epsilon)
                else:
                    ratio = 0
                    
                phase_flow_ratios.append(ratio)
            
            episode_flow_ratios.append(phase_flow_ratios)
            print(f"Episode {episode+1} | Action {action:2d} | Flow Ratios: {[f'{r:.2f}' for r in phase_flow_ratios]} | Wait: {avg_action_wait:.1f}")
            
            # Update step counter
            step += action_duration
        
        # Calculate episode metrics
        total_vehicles = len(vehicle_counts)
        waiting_time_per_vehicle = total_waiting_time / total_vehicles if total_vehicles > 0 else 0
        
        print(f"\nEpisode {episode+1} Summary:")
        print(f"Total Wait Time: {total_waiting_time:.1f}")
        print(f"Total Vehicles: {total_vehicles}")
        print(f"Wait Time per Vehicle: {waiting_time_per_vehicle:.1f}")
        print("-" * 50)
        
        # Store episode data
        all_actions.append(episode_actions)
        all_flow_ratios.append(episode_flow_ratios)
        all_waiting_times.append(episode_waiting_times)
        
        # Clean up
        environment.close_simulation()
    
    # Analyze the collected data
    analyze_flow_ratio_data(all_actions, all_flow_ratios, all_waiting_times)
    
    return all_actions, all_flow_ratios, all_waiting_times


def analyze_flow_ratio_data(actions, flow_ratios, waiting_times):
    """Analyze flow ratio data to find patterns and correlations."""
    # Flatten the data for analysis
    flat_actions = [action for episode_actions in actions for action in episode_actions]
    flat_flow_ratios = [ratio for episode_ratios in flow_ratios for ratio in episode_ratios]
    flat_waiting_times = [time for episode_times in waiting_times for time in episode_times]
    
    # Calculate average flow ratio for each action
    action_to_flow = defaultdict(list)
    action_to_wait = defaultdict(list)
    
    for action, ratios, wait in zip(flat_actions, flat_flow_ratios, flat_waiting_times):
        # Average flow ratio across all phases
        avg_ratio = sum(ratios) / len(ratios)
        action_to_flow[action].append(avg_ratio)
        action_to_wait[action].append(wait)
    
    # Calculate mean and std for each action
    action_stats = {}
    for action in action_to_flow:
        avg_flow = np.mean(action_to_flow[action])
        std_flow = np.std(action_to_flow[action])
        avg_wait = np.mean(action_to_wait[action])
        std_wait = np.std(action_to_wait[action])
        action_stats[action] = {
            'avg_flow': avg_flow,
            'std_flow': std_flow,
            'avg_wait': avg_wait,
            'std_wait': std_wait,
            'count': len(action_to_flow[action])
        }
    
    # Print action statistics
    print("\nAction Statistics:")
    print("Action | Avg Flow Ratio | Flow Std Dev | Avg Wait Time | Wait Std Dev | Count")
    print("-" * 80)
    
    for action, stats in sorted(action_stats.items()):
        print(f"{action:5d} | {stats['avg_flow']:13.2f} | {stats['std_flow']:11.2f} | {stats['avg_wait']:12.1f} | {stats['std_wait']:11.1f} | {stats['count']:5d}")
    
    # Calculate flow ratio bin distribution
    bins = {'low': 0, 'medium': 0, 'high': 0}
    for episode_ratios in flow_ratios:
        for phase_ratios in episode_ratios:
            for ratio in phase_ratios:
                if ratio < 0.8:
                    bins['low'] += 1
                elif ratio < 1.2:
                    bins['medium'] += 1
                else:
                    bins['high'] += 1
    
    total_ratios = sum(bins.values())
    print("\nFlow Ratio Distribution:")
    print(f"Low (<0.8): {bins['low']} ({bins['low']/total_ratios*100:.1f}%)")
    print(f"Medium (0.8-1.2): {bins['medium']} ({bins['medium']/total_ratios*100:.1f}%)")
    print(f"High (>1.2): {bins['high']} ({bins['high']/total_ratios*100:.1f}%)")
    
    # Calculate correlation between flow ratio and waiting time
    flat_avg_ratios = [sum(ratios)/len(ratios) for ratios in flat_flow_ratios]
    correlation = np.corrcoef(flat_avg_ratios, flat_waiting_times)[0, 1]
    print(f"\nCorrelation between flow ratio and waiting time: {correlation:.3f}")
    
    # Visualize the data
    plt.figure(figsize=(12, 8))
    
    # Plot 1: Flow Ratio Distribution
    plt.subplot(2, 2, 1)
    plt.bar(['Low', 'Medium', 'High'], [bins['low'], bins['medium'], bins['high']])
    plt.title('Flow Ratio Distribution')
    plt.ylabel('Count')
    
    # Plot 2: Average Flow Ratio by Action
    actions_list = sorted(action_stats.keys())
    avg_flows = [action_stats[a]['avg_flow'] for a in actions_list]
    
    plt.subplot(2, 2, 2)
    plt.bar(actions_list, avg_flows)
    plt.title('Average Flow Ratio by Action')
    plt.xlabel('Action')
    plt.ylabel('Avg Flow Ratio')
    
    # Plot 3: Average Wait Time by Action
    avg_waits = [action_stats[a]['avg_wait'] for a in actions_list]
    
    plt.subplot(2, 2, 3)
    plt.bar(actions_list, avg_waits)
    plt.title('Average Wait Time by Action')
    plt.xlabel('Action')
    plt.ylabel('Avg Wait Time')
    
    # Plot 4: Flow Ratio vs Wait Time Scatter
    plt.subplot(2, 2, 4)
    plt.scatter(flat_avg_ratios, flat_waiting_times, alpha=0.5)
    plt.title(f'Flow Ratio vs Wait Time (Corr: {correlation:.3f})')
    plt.xlabel('Average Flow Ratio')
    plt.ylabel('Wait Time')
    
    plt.tight_layout()
    plt.savefig('flow_ratio_analysis.png')
    plt.close()
    

if __name__ == "__main__":
    from environment import Environment
    
    # Define configuration (use your actual config paths)
    sumo_binary = "sumo-gui"  # or "sumo" for non-GUI mode
    sumo_config = r"C:\Users\Administrator\Desktop\MySumo\Stage 10\SUMO files\stage10.sumocfg"
    
    # Create environment instance
    env = Environment(sumo_config, sumo_binary)
    
    # Run analysis
    actions, flow_ratios, waiting_times = analyze_random_actions(
        environment=env,
        episodes=5,
        total_sim_time=3600,
        action_duration=80
    )
    
    print("\nAnalysis complete! Results saved to flow_ratio_analysis.png")
# Out:
# Random Action Analysis
# Format: Episode | Action | Flow Ratios | Avg Wait Time
# ---------------------------------------------------------------------------
# Episode 1 | Action  7 | Flow Ratios: ['0.00', '0.00', '0.00', '0.00'] | Wait: 0.8
# Episode 1 | Action  7 | Flow Ratios: ['0.41', '0.08', '0.06', '0.00'] | Wait: 17.6
# Episode 1 | Action 21 | Flow Ratios: ['0.13', '0.71', '0.12', '0.29'] | Wait: 733.9
# Episode 1 | Action  2 | Flow Ratios: ['0.76', '0.25', '0.45', '0.33'] | Wait: 1264.5
# Episode 1 | Action 11 | Flow Ratios: ['0.69', '0.36', '0.12', '0.60'] | Wait: 2680.2
# Episode 1 | Action 18 | Flow Ratios: ['0.47', '0.25', '0.35', '0.29'] | Wait: 3481.3
# Episode 1 | Action 29 | Flow Ratios: ['0.33', '0.18', '0.65', '0.33'] | Wait: 4110.5
# Episode 1 | Action 33 | Flow Ratios: ['0.28', '0.56', '0.23', '0.62'] | Wait: 5183.6
# Episode 1 | Action  9 | Flow Ratios: ['0.29', '0.86', '0.25', '1.00'] | Wait: 5852.8
# Episode 1 | Action  6 | Flow Ratios: ['0.33', '0.83', '3.00', '0.13'] | Wait: 6302.1
# Episode 1 | Action 20 | Flow Ratios: ['6.00', '0.17', '5.00', '0.38'] | Wait: 5574.8
# Episode 1 | Action 20 | Flow Ratios: ['3.00', '0.50', '0.90', '0.38'] | Wait: 5617.4
# Episode 1 | Action  4 | Flow Ratios: ['1.80', '0.67', '0.62', '0.71'] | Wait: 5936.0
# Episode 1 | Action  0 | Flow Ratios: ['1.75', '1.50', '0.22', '1.12'] | Wait: 6057.0
# Episode 1 | Action 12 | Flow Ratios: ['0.25', '2.50', '1.80', '0.36'] | Wait: 7107.9
# Episode 1 | Action 21 | Flow Ratios: ['0.25', '1.87', '1.00', '0.37'] | Wait: 7717.6
# Episode 1 | Action 29 | Flow Ratios: ['1.25', '0.25', '2.60', '0.50'] | Wait: 6751.5
# Episode 1 | Action  2 | Flow Ratios: ['4.00', '0.50', '0.75', '1.00'] | Wait: 5801.8
# Episode 1 | Action 16 | Flow Ratios: ['0.33', '2.50', '0.42', '2.67'] | Wait: 6741.3
# Episode 1 | Action 12 | Flow Ratios: ['0.20', '1.00', '3.00', '1.67'] | Wait: 7148.9
# Episode 1 | Action 33 | Flow Ratios: ['2.50', '1.25', '0.33', '0.83'] | Wait: 6539.3
# Episode 1 | Action 21 | Flow Ratios: ['1.00', '2.00', '0.29', '0.29'] | Wait: 6939.2
# Episode 1 | Action 10 | Flow Ratios: ['0.60', '0.90', '9.00', '0.50'] | Wait: 7395.7
# Episode 1 | Action 19 | Flow Ratios: ['0.67', '0.53', '0.60', '2.67'] | Wait: 6217.1
# Episode 1 | Action  1 | Flow Ratios: ['4.50', '0.43', '1.14', '0.50'] | Wait: 5840.7
# Episode 1 | Action 18 | Flow Ratios: ['2.67', '5.00', '1.00', '0.50'] | Wait: 6341.4
# Episode 1 | Action 31 | Flow Ratios: ['0.56', '1.25', '1.33', '1.00'] | Wait: 6778.4
# Episode 1 | Action  0 | Flow Ratios: ['1.14', '0.29', '0.33', '8.00'] | Wait: 6024.4
# Episode 1 | Action  1 | Flow Ratios: ['1.33', '1.00', '1.12', '0.22'] | Wait: 6487.8
# Episode 1 | Action  7 | Flow Ratios: ['0.60', '6.00', '0.33', '0.60'] | Wait: 7480.9
# Episode 1 | Action 31 | Flow Ratios: ['0.45', '0.62', '3.33', '2.00'] | Wait: 6859.1
# Episode 1 | Action 13 | Flow Ratios: ['1.00', '0.71', '0.60', '2.00'] | Wait: 5804.6
# Episode 1 | Action 27 | Flow Ratios: ['0.50', '0.50', '0.29', '2.33'] | Wait: 5986.4
# Episode 1 | Action 34 | Flow Ratios: ['0.56', '1.25', '1.00', '1.14'] | Wait: 6967.4
# Episode 1 | Action 13 | Flow Ratios: ['9.00', '1.00', '1.50', '0.36'] | Wait: 6653.1
# Episode 1 | Action  3 | Flow Ratios: ['3.50', '0.60', '1.00', '0.29'] | Wait: 5986.3
# Episode 1 | Action 34 | Flow Ratios: ['0.60', '2.00', '1.50', '2.33'] | Wait: 7131.3
# Episode 1 | Action 34 | Flow Ratios: ['0.43', '0.83', '1.00', '2.00'] | Wait: 7081.8
# Episode 1 | Action 26 | Flow Ratios: ['1.00', '0.60', '1.00', '1.50'] | Wait: 6301.7
# Episode 1 | Action 11 | Flow Ratios: ['2.60', '3.00', '1.00', '0.22'] | Wait: 6545.8
# Episode 1 | Action 26 | Flow Ratios: ['0.86', '0.50', '1.00', '1.50'] | Wait: 6303.1
# Episode 1 | Action 27 | Flow Ratios: ['0.15', '1.50', '1.00', '3.00'] | Wait: 6504.3
# Episode 1 | Action 21 | Flow Ratios: ['0.50', '13.00', '1.50', '0.15'] | Wait: 8253.0
# Episode 1 | Action  9 | Flow Ratios: ['1.00', '0.91', '6000000.00', '0.62'] | Wait: 7733.9
# Episode 1 | Action 11 | Flow Ratios: ['14.00', '0.40', '0.50', '0.67'] | Wait: 5676.1
#
# Episode 1 Summary:
# Total Wait Time: 20793149.0
# Total Vehicles: 1281
# Wait Time per Vehicle: 16232.0
# --------------------------------------------------
# Episode 2 | Action  1 | Flow Ratios: ['0.00', '0.00', '0.00', '0.00'] | Wait: 0.8
# Episode 2 | Action 25 | Flow Ratios: ['0.12', '0.08', '0.06', '0.14'] | Wait: 6.9
# Episode 2 | Action 17 | Flow Ratios: ['0.19', '0.24', '0.69', '0.29'] | Wait: 854.3
# Episode 2 | Action 15 | Flow Ratios: ['0.18', '0.50', '0.27', '2.00'] | Wait: 1684.8
# Episode 2 | Action 25 | Flow Ratios: ['0.12', '0.14', '0.35', '2.00'] | Wait: 2955.1
# Episode 2 | Action 18 | Flow Ratios: ['0.62', '0.29', '0.28', '0.29'] | Wait: 3849.2
# Episode 2 | Action 24 | Flow Ratios: ['0.67', '0.12', '0.81', '0.83'] | Wait: 3661.3
# Episode 2 | Action 15 | Flow Ratios: ['0.37', '0.33', '0.17', '1.37'] | Wait: 4719.3
# Episode 2 | Action 10 | Flow Ratios: ['1.00', '1.67', '0.64', '0.60'] | Wait: 5595.3
# Episode 2 | Action  9 | Flow Ratios: ['2.00', '1.37', '0.67', '0.33'] | Wait: 5412.3
# Episode 2 | Action 32 | Flow Ratios: ['1.67', '0.50', '1.00', '0.46'] | Wait: 4771.1
# Episode 2 | Action  2 | Flow Ratios: ['5.00', '0.29', '0.83', '0.15'] | Wait: 4654.8
# Episode 2 | Action  1 | Flow Ratios: ['1.00', '0.67', '1.00', '0.29'] | Wait: 5573.8
# Episode 2 | Action 24 | Flow Ratios: ['0.17', '1.00', '2.60', '0.75'] | Wait: 6234.7
# Episode 2 | Action 22 | Flow Ratios: ['0.29', '1.00', '1.56', '0.18'] | Wait: 6366.6
# Episode 2 | Action 26 | Flow Ratios: ['6.00', '1.00', '0.25', '0.62'] | Wait: 5735.5
# Episode 2 | Action 18 | Flow Ratios: ['5.00', '2.50', '0.55', '0.20'] | Wait: 6452.4
# Episode 2 | Action 33 | Flow Ratios: ['1.00', '1.33', '0.50', '0.56'] | Wait: 6641.0
# Episode 2 | Action 32 | Flow Ratios: ['0.57', '0.67', '1.25', '1.20'] | Wait: 6445.8
# Episode 2 | Action 14 | Flow Ratios: ['0.33', '2.00', '1.50', '1.20'] | Wait: 6746.9
# Episode 2 | Action  3 | Flow Ratios: ['2.80', '0.25', '0.75', '0.50'] | Wait: 5924.8
# Episode 2 | Action 22 | Flow Ratios: ['0.33', '1.50', '2.67', '0.22'] | Wait: 7192.1
# Episode 2 | Action 25 | Flow Ratios: ['0.25', '1.00', '0.83', '30000000.00'] | Wait: 7819.6
# Episode 2 | Action 19 | Flow Ratios: ['0.67', '2.67', '0.14', '1.50'] | Wait: 6851.0
# Episode 2 | Action  6 | Flow Ratios: ['1.00', '1.30', '2.50', '0.22'] | Wait: 7223.7
# Episode 2 | Action 11 | Flow Ratios: ['5.50', '0.56', '2.00', '0.40'] | Wait: 6364.3
# Episode 2 | Action  6 | Flow Ratios: ['0.67', '1.75', '0.75', '0.33'] | Wait: 6911.4
# Episode 2 | Action 34 | Flow Ratios: ['0.60', '0.67', '3.00', '27000000.00'] | Wait: 7513.8
# Episode 2 | Action 10 | Flow Ratios: ['0.67', '0.90', '1.43', '0.29'] | Wait: 6406.4
# Episode 2 | Action 23 | Flow Ratios: ['0.83', '0.43', '6.00', '1.75'] | Wait: 6632.0
# Episode 2 | Action  5 | Flow Ratios: ['9.00', '4.00', '0.25', '0.33'] | Wait: 6363.0
# Episode 2 | Action  8 | Flow Ratios: ['2.00', '0.20', '1.50', '1.00'] | Wait: 5780.6
# Episode 2 | Action 29 | Flow Ratios: ['0.40', '2.00', '2.75', '0.50'] | Wait: 6601.2
# Episode 2 | Action 18 | Flow Ratios: ['0.75', '2.50', '1.00', '2.00'] | Wait: 7110.4
# Episode 2 | Action 17 | Flow Ratios: ['0.25', '1.50', '1.22', '1.00'] | Wait: 6773.4
# Episode 2 | Action 13 | Flow Ratios: ['0.73', '1.00', '0.50', '5.00'] | Wait: 6663.6
# Episode 2 | Action 21 | Flow Ratios: ['1.00', '2.50', '0.22', '0.33'] | Wait: 7230.1
# Episode 2 | Action 21 | Flow Ratios: ['0.33', '1.70', '9000000.00', '2.00'] | Wait: 8200.5
# Episode 2 | Action 18 | Flow Ratios: ['7.00', '0.37', '3.00', '1.00'] | Wait: 6104.0
# Episode 2 | Action 12 | Flow Ratios: ['1.00', '0.50', '1.14', '1.67'] | Wait: 6154.8
# Episode 2 | Action 31 | Flow Ratios: ['0.62', '1.67', '1.29', '1.50'] | Wait: 6813.8
# Episode 2 | Action 31 | Flow Ratios: ['2.50', '0.71', '1.00', '0.40'] | Wait: 6213.0
# Episode 2 | Action  3 | Flow Ratios: ['3.40', '0.40', '0.33', '1.00'] | Wait: 5692.1
# Episode 2 | Action 25 | Flow Ratios: ['0.33', '0.67', '0.83', '3.00'] | Wait: 6626.8
# Episode 2 | Action 25 | Flow Ratios: ['0.14', '1.00', '0.71', '2.75'] | Wait: 7028.1
#
# Episode 2 Summary:
# Total Wait Time: 20524460.0
# Total Vehicles: 1289
# Wait Time per Vehicle: 15922.8
# --------------------------------------------------
# Episode 3 | Action 33 | Flow Ratios: ['0.00', '0.00', '0.00', '0.00'] | Wait: 0.7
# Episode 3 | Action 21 | Flow Ratios: ['0.12', '0.08', '0.06', '0.14'] | Wait: 22.4
# Episode 3 | Action 27 | Flow Ratios: ['0.19', '0.11', '0.12', '1.43'] | Wait: 957.0
# Episode 3 | Action 17 | Flow Ratios: ['0.18', '0.55', '1.18', '0.33'] | Wait: 2019.4
# Episode 3 | Action 25 | Flow Ratios: ['0.12', '0.21', '0.35', '2.00'] | Wait: 2595.2
# Episode 3 | Action 20 | Flow Ratios: ['0.37', '0.12', '0.50', '0.71'] | Wait: 3768.6
# Episode 3 | Action 34 | Flow Ratios: ['1.67', '0.29', '0.20', '1.33'] | Wait: 4391.0
# Episode 3 | Action  1 | Flow Ratios: ['2.25', '0.14', '0.47', '0.25'] | Wait: 4458.3
# Episode 3 | Action 31 | Flow Ratios: ['1.00', '4.00', '0.69', '0.40'] | Wait: 5050.6
# Episode 3 | Action  3 | Flow Ratios: ['1.62', '0.50', '0.33', '0.13'] | Wait: 4666.1
# Episode 3 | Action  7 | Flow Ratios: ['0.56', '4.33', '0.50', '0.23'] | Wait: 6254.0
# Episode 3 | Action 34 | Flow Ratios: ['0.36', '0.67', '2.00', '0.54'] | Wait: 5600.5
# Episode 3 | Action 22 | Flow Ratios: ['0.75', '0.25', '3.20', '0.43'] | Wait: 5899.2
# Episode 3 | Action  7 | Flow Ratios: ['0.83', '5.00', '0.50', '0.25'] | Wait: 6313.9
# Episode 3 | Action 26 | Flow Ratios: ['7.00', '0.20', '0.17', '1.00'] | Wait: 5119.7
# Episode 3 | Action  1 | Flow Ratios: ['2.00', '0.50', '2.25', '0.12'] | Wait: 6059.1
# Episode 3 | Action  1 | Flow Ratios: ['1.33', '0.67', '1.33', '0.15'] | Wait: 6411.4
# Episode 3 | Action 18 | Flow Ratios: ['1.00', '2.50', '0.62', '2.00'] | Wait: 6609.7
# Episode 3 | Action 12 | Flow Ratios: ['0.27', '1.00', '1.50', '1.25'] | Wait: 7002.0
# Episode 3 | Action 20 | Flow Ratios: ['0.71', '0.33', '1.80', '3.00'] | Wait: 6656.7
# Episode 3 | Action  2 | Flow Ratios: ['2.75', '1.50', '0.55', '0.29'] | Wait: 5914.3
# Episode 3 | Action  5 | Flow Ratios: ['2.00', '8.00', '0.22', '0.40'] | Wait: 6956.4
# Episode 3 | Action 16 | Flow Ratios: ['0.18', '0.75', '2.50', '9.00'] | Wait: 6999.3
# Episode 3 | Action 27 | Flow Ratios: ['0.20', '0.40', '0.75', '4.67'] | Wait: 6311.5
# Episode 3 | Action 24 | Flow Ratios: ['2.00', '0.67', '3.00', '0.46'] | Wait: 6866.9
# Episode 3 | Action 12 | Flow Ratios: ['1.00', '2.50', '1.33', '0.45'] | Wait: 6974.6
# Episode 3 | Action 15 | Flow Ratios: ['0.67', '0.75', '0.30', '2.75'] | Wait: 6333.2
# Episode 3 | Action 12 | Flow Ratios: ['2.00', '2.00', '1.25', '0.44'] | Wait: 6511.9
# Episode 3 | Action 23 | Flow Ratios: ['2.50', '0.33', '2.00', '1.00'] | Wait: 6368.7
# Episode 3 | Action  1 | Flow Ratios: ['4.50', '1.00', '0.90', '0.25'] | Wait: 6093.3
# Episode 3 | Action  3 | Flow Ratios: ['2.33', '1.00', '0.50', '0.33'] | Wait: 5936.0
# Episode 3 | Action 21 | Flow Ratios: ['0.18', '3.75', '0.50', '0.67'] | Wait: 8494.1
# Episode 3 | Action 24 | Flow Ratios: ['0.11', '0.37', '36000000.00', '15000000.00'] | Wait: 8587.7
# Episode 3 | Action 11 | Flow Ratios: ['4.00', '0.62', '0.22', '0.67'] | Wait: 5905.6
# Episode 3 | Action 13 | Flow Ratios: ['4.00', '1.20', '0.25', '1.00'] | Wait: 6454.2
# Episode 3 | Action 32 | Flow Ratios: ['0.45', '1.67', '3.00', '1.67'] | Wait: 7043.2
# Episode 3 | Action 21 | Flow Ratios: ['0.37', '2.00', '0.40', '0.50'] | Wait: 7436.9
# Episode 3 | Action 24 | Flow Ratios: ['0.33', '0.33', '6.50', '1.67'] | Wait: 7256.5
# Episode 3 | Action  3 | Flow Ratios: ['8.00', '0.40', '0.25', '1.50'] | Wait: 5980.9
# Episode 3 | Action  9 | Flow Ratios: ['1.00', '5.50', '0.50', '0.67'] | Wait: 7903.8
# Episode 3 | Action  8 | Flow Ratios: ['0.79', '0.20', '2.00', '18000000.00'] | Wait: 7258.1
# Episode 3 | Action  6 | Flow Ratios: ['1.50', '2.40', '1.00', '0.20'] | Wait: 7585.2
# Episode 3 | Action  1 | Flow Ratios: ['0.75', '0.30', '4.50', '6000000.00'] | Wait: 7721.3
# Episode 3 | Action 34 | Flow Ratios: ['1.25', '1.25', '0.30', '2.00'] | Wait: 5943.8
# Episode 3 | Action  8 | Flow Ratios: ['2.00', '0.40', '0.75', '1.50'] | Wait: 6033.0
#
# Episode 3 Summary:
# Total Wait Time: 20858058.0
# Total Vehicles: 1280
# Wait Time per Vehicle: 16295.4
# --------------------------------------------------
# Episode 4 | Action  2 | Flow Ratios: ['0.00', '0.00', '0.00', '0.00'] | Wait: 0.8
# Episode 4 | Action  3 | Flow Ratios: ['0.41', '0.08', '0.06', '0.00'] | Wait: 7.2
# Episode 4 | Action  1 | Flow Ratios: ['0.53', '0.11', '0.50', '0.29'] | Wait: 583.8
# Episode 4 | Action 33 | Flow Ratios: ['0.35', '0.91', '0.27', '0.83'] | Wait: 1633.5
# Episode 4 | Action 30 | Flow Ratios: ['0.31', '0.57', '0.35', '0.40'] | Wait: 2726.2
# Episode 4 | Action 33 | Flow Ratios: ['0.29', '0.56', '0.11', '0.86'] | Wait: 3106.4
# Episode 4 | Action  6 | Flow Ratios: ['0.12', '0.76', '0.31', '0.33'] | Wait: 4539.2
# Episode 4 | Action 23 | Flow Ratios: ['0.83', '0.12', '0.46', '1.00'] | Wait: 4755.6
# Episode 4 | Action 11 | Flow Ratios: ['3.33', '0.36', '0.30', '0.50'] | Wait: 5163.7
# Episode 4 | Action 27 | Flow Ratios: ['0.33', '0.13', '0.67', '0.93'] | Wait: 5151.2
# Episode 4 | Action 17 | Flow Ratios: ['0.17', '1.25', '4.33', '0.23'] | Wait: 7030.1
# Episode 4 | Action 30 | Flow Ratios: ['2.50', '1.40', '2.00', '0.15'] | Wait: 6161.4
# Episode 4 | Action 18 | Flow Ratios: ['9.00', '0.62', '0.56', '0.29'] | Wait: 5311.7
# Episode 4 | Action 24 | Flow Ratios: ['0.75', '0.40', '1.50', '0.62'] | Wait: 5826.3
# Episode 4 | Action  5 | Flow Ratios: ['1.12', '2.50', '0.37', '0.18'] | Wait: 6264.2
# Episode 4 | Action 34 | Flow Ratios: ['4.00', '0.62', '0.37', '0.64'] | Wait: 5821.7
# Episode 4 | Action 31 | Flow Ratios: ['0.44', '1.00', '2.50', '0.40'] | Wait: 6676.5
# Episode 4 | Action 14 | Flow Ratios: ['0.60', '2.00', '1.25', '1.00'] | Wait: 6820.5
# Episode 4 | Action 14 | Flow Ratios: ['0.29', '1.25', '0.62', '2.50'] | Wait: 6388.4
# Episode 4 | Action 13 | Flow Ratios: ['3.00', '0.60', '0.50', '0.83'] | Wait: 5976.4
# Episode 4 | Action  5 | Flow Ratios: ['4.50', '1.33', '0.50', '0.22'] | Wait: 6421.8
# Episode 4 | Action  2 | Flow Ratios: ['1.22', '0.33', '5.00', '1.00'] | Wait: 6302.0
# Episode 4 | Action  0 | Flow Ratios: ['1.12', '0.67', '0.33', '2.67'] | Wait: 6306.6
# Episode 4 | Action  8 | Flow Ratios: ['0.92', '1.00', '0.67', '1.20'] | Wait: 6606.2
# Episode 4 | Action  1 | Flow Ratios: ['0.70', '1.50', '3.00', '0.22'] | Wait: 7092.3
# Episode 4 | Action 13 | Flow Ratios: ['0.80', '5.00', '0.40', '2.50'] | Wait: 7095.1
# Episode 4 | Action 25 | Flow Ratios: ['0.22', '0.50', '1.20', '2.40'] | Wait: 6476.7
# Episode 4 | Action 25 | Flow Ratios: ['0.29', '0.67', '1.00', '2.20'] | Wait: 6809.9
# Episode 4 | Action 27 | Flow Ratios: ['0.40', '1.00', '0.60', '1.08'] | Wait: 6499.9
# Episode 4 | Action  7 | Flow Ratios: ['1.50', '5.50', '1.50', '0.14'] | Wait: 7872.5
# Episode 4 | Action 25 | Flow Ratios: ['1.00', '0.22', '5.00', '1.25'] | Wait: 7057.7
# Episode 4 | Action  0 | Flow Ratios: ['1.29', '0.67', '0.29', '1.80'] | Wait: 6291.6
# Episode 4 | Action 17 | Flow Ratios: ['1.00', '2.50', '3.67', '0.17'] | Wait: 7695.1
# Episode 4 | Action  6 | Flow Ratios: ['0.20', '3.00', '1.50', '1.00'] | Wait: 8073.6
# Episode 4 | Action 25 | Flow Ratios: ['2.00', '0.25', '0.67', '3.33'] | Wait: 6254.6
# Episode 4 | Action 24 | Flow Ratios: ['1.00', '0.40', '1.50', '1.00'] | Wait: 6717.0
# Episode 4 | Action 13 | Flow Ratios: ['9.00', '2.50', '0.33', '0.75'] | Wait: 6699.5
# Episode 4 | Action 20 | Flow Ratios: ['1.67', '0.33', '1.29', '0.67'] | Wait: 6305.9
# Episode 4 | Action 30 | Flow Ratios: ['0.56', '4.50', '0.83', '0.67'] | Wait: 7126.5
# Episode 4 | Action 22 | Flow Ratios: ['0.50', '0.33', '3.50', '0.67'] | Wait: 6539.9
# Episode 4 | Action  6 | Flow Ratios: ['0.40', '6.50', '0.60', '0.67'] | Wait: 7270.8
# Episode 4 | Action 28 | Flow Ratios: ['3.00', '0.20', '0.90', '8.00'] | Wait: 6397.4
# Episode 4 | Action 24 | Flow Ratios: ['1.50', '0.50', '1.20', '1.00'] | Wait: 6517.6
# Episode 4 | Action 25 | Flow Ratios: ['1.00', '1.50', '0.75', '2.00'] | Wait: 6437.9
# Episode 4 | Action  2 | Flow Ratios: ['3.67', '1.00', '0.50', '0.25'] | Wait: 6047.2
#
# Episode 4 Summary:
# Total Wait Time: 20708806.0
# Total Vehicles: 1280
# Wait Time per Vehicle: 16178.8
# --------------------------------------------------
# Episode 5 | Action 13 | Flow Ratios: ['0.00', '0.00', '0.00', '0.00'] | Wait: 0.7
# Episode 5 | Action 16 | Flow Ratios: ['0.12', '0.08', '0.06', '0.14'] | Wait: 9.6
# Episode 5 | Action 11 | Flow Ratios: ['0.80', '0.24', '0.12', '0.29'] | Wait: 664.8
# Episode 5 | Action 24 | Flow Ratios: ['0.17', '0.25', '1.18', '0.83'] | Wait: 1969.9
# Episode 5 | Action  0 | Flow Ratios: ['0.56', '0.21', '0.18', '1.80'] | Wait: 2392.6
# Episode 5 | Action 15 | Flow Ratios: ['0.19', '0.31', '0.12', '1.57'] | Wait: 3781.7
# Episode 5 | Action  6 | Flow Ratios: ['0.12', '0.65', '0.31', '0.33'] | Wait: 5114.6
# Episode 5 | Action 29 | Flow Ratios: ['1.67', '0.19', '0.87', '0.25'] | Wait: 4579.4
# Episode 5 | Action 31 | Flow Ratios: ['1.67', '0.60', '0.90', '0.40'] | Wait: 4806.6
# Episode 5 | Action 11 | Flow Ratios: ['1.67', '1.00', '0.30', '0.13'] | Wait: 4554.9
# Episode 5 | Action  8 | Flow Ratios: ['1.71', '0.50', '0.29', '0.38'] | Wait: 4571.1
# Episode 5 | Action 30 | Flow Ratios: ['0.55', '2.67', '3.00', '0.23'] | Wait: 6784.4
# Episode 5 | Action 18 | Flow Ratios: ['0.82', '0.56', '2.50', '0.29'] | Wait: 5980.8
# Episode 5 | Action 26 | Flow Ratios: ['2.00', '0.40', '0.25', '1.25'] | Wait: 5414.8
# Episode 5 | Action  8 | Flow Ratios: ['1.11', '1.00', '0.43', '0.45'] | Wait: 6078.4
# Episode 5 | Action 18 | Flow Ratios: ['1.50', '2.00', '3.50', '0.19'] | Wait: 6873.6
# Episode 5 | Action  5 | Flow Ratios: ['0.67', '1.60', '1.00', '0.33'] | Wait: 7045.4
# Episode 5 | Action 17 | Flow Ratios: ['0.22', '0.67', '3.00', '1.00'] | Wait: 6907.2
# Episode 5 | Action 25 | Flow Ratios: ['0.29', '0.40', '1.00', '10.00'] | Wait: 6753.5
# Episode 5 | Action 10 | Flow Ratios: ['1.00', '3.33', '0.75', '0.29'] | Wait: 7070.9
# Episode 5 | Action 33 | Flow Ratios: ['3.00', '1.00', '1.00', '0.62'] | Wait: 6846.3
# Episode 5 | Action 16 | Flow Ratios: ['1.00', '0.70', '0.71', '2.00'] | Wait: 5993.1
# Episode 5 | Action  1 | Flow Ratios: ['1.33', '0.50', '1.80', '0.50'] | Wait: 6199.9
# Episode 5 | Action 32 | Flow Ratios: ['3.00', '2.50', '0.67', '1.00'] | Wait: 6372.4
# Episode 5 | Action 21 | Flow Ratios: ['0.20', '2.67', '0.50', '0.40'] | Wait: 7203.6
# Episode 5 | Action  0 | Flow Ratios: ['2.00', '0.20', '0.50', '2.00'] | Wait: 6655.9
# Episode 5 | Action 27 | Flow Ratios: ['0.67', '0.25', '0.67', '1.87'] | Wait: 6157.1
# Episode 5 | Action 32 | Flow Ratios: ['0.50', '1.67', '3.00', '0.62'] | Wait: 7407.2
# Episode 5 | Action 13 | Flow Ratios: ['4.00', '1.25', '0.50', '0.42'] | Wait: 6487.5
# Episode 5 | Action 10 | Flow Ratios: ['0.50', '2.00', '2.00', '0.29'] | Wait: 7060.1
# Episode 5 | Action 27 | Flow Ratios: ['0.15', '0.25', '1.50', '13.00'] | Wait: 7004.1
# Episode 5 | Action 14 | Flow Ratios: ['0.67', '4.00', '0.56', '0.71'] | Wait: 7274.3
# Episode 5 | Action  8 | Flow Ratios: ['6.50', '0.29', '1.00', '0.56'] | Wait: 6582.6
# Episode 5 | Action 13 | Flow Ratios: ['2.33', '6.00', '0.60', '0.62'] | Wait: 6719.8
# Episode 5 | Action 23 | Flow Ratios: ['0.50', '0.40', '2.00', '1.60'] | Wait: 6882.6
# Episode 5 | Action  6 | Flow Ratios: ['0.22', '5.50', '1.25', '0.50'] | Wait: 7639.5
# Episode 5 | Action 10 | Flow Ratios: ['0.67', '0.80', '9.00', '0.40'] | Wait: 7499.5
# Episode 5 | Action 24 | Flow Ratios: ['0.67', '0.25', '1.71', '1.67'] | Wait: 6465.5
# Episode 5 | Action 11 | Flow Ratios: ['6.00', '3.50', '0.18', '1.50'] | Wait: 6188.4
# Episode 5 | Action 29 | Flow Ratios: ['2.00', '0.33', '1.57', '0.29'] | Wait: 6497.7
# Episode 5 | Action 29 | Flow Ratios: ['0.50', '0.67', '2.00', '2.00'] | Wait: 7372.4
# Episode 5 | Action  8 | Flow Ratios: ['2.40', '2.00', '0.17', '2.50'] | Wait: 6185.4
# Episode 5 | Action 13 | Flow Ratios: ['1.50', '1.67', '0.40', '1.00'] | Wait: 6770.8
# Episode 5 | Action 14 | Flow Ratios: ['0.23', '2.00', '1.67', '1.25'] | Wait: 7516.9
# Episode 5 | Action 32 | Flow Ratios: ['0.86', '0.83', '1.67', '2.50'] | Wait: 7002.5
#
# Episode 5 Summary:
# Total Wait Time: 20907175.0
# Total Vehicles: 1275
# Wait Time per Vehicle: 16397.8
# --------------------------------------------------
#
# Action Statistics:
# Action | Avg Flow Ratio | Flow Std Dev | Avg Wait Time | Wait Std Dev | Count
# --------------------------------------------------------------------------------
#     0 |          1.28 |        0.55 |       5621.3 |      1458.7 |     6
#     1 |     125001.00 |   414578.22 |       5210.2 |      2328.1 |    12
#     2 |          1.16 |        0.63 |       4283.6 |      2382.8 |     7
#     3 |          1.15 |        0.68 |       4884.8 |      2038.6 |     7
#     4 |          0.95 |        0.00 |       5936.0 |         0.0 |     1
#     5 |          1.93 |        0.96 |       6610.2 |       324.2 |     5
#     6 |          1.17 |        0.55 |       6740.0 |      1131.6 |     9
#     7 |          1.21 |        0.84 |       4656.6 |      3337.0 |     6
#     8 |     562501.17 |  1488234.95 |       6136.9 |       730.7 |     8
#     9 |     375001.06 |   649518.81 |       6725.7 |      1105.8 |     4
#    10 |          1.63 |        0.79 |       6838.0 |       656.1 |     6
#    11 |          1.62 |        1.09 |       4860.4 |      1860.9 |     9
#    12 |          1.25 |        0.17 |       6816.7 |       361.8 |     6
#    13 |          1.74 |        0.86 |       5938.7 |      1909.3 |    11
#    14 |          1.28 |        0.11 |       6949.4 |       400.0 |     5
#    15 |          0.74 |        0.23 |       4129.7 |      1680.9 |     4
#    16 |          1.45 |        1.08 |       4935.8 |      2868.0 |     4
#    17 |          1.08 |        0.51 |       5213.3 |      2706.9 |     6
#    18 |          1.65 |        0.82 |       5811.4 |      1174.2 |    10
#    19 |          1.18 |        0.06 |       6534.0 |       317.0 |     2
#    20 |          1.39 |        0.82 |       5584.7 |       996.9 |     5
#    21 |     225001.10 |   674999.97 |       6223.1 |      2965.9 |    10
#    22 |          1.09 |        0.19 |       6499.4 |       463.5 |     4
#    23 |          1.36 |        0.60 |       6159.7 |       830.8 |     4
#    24 |    1275001.01 |  3824999.70 |       6010.3 |      1783.8 |    10
#    25 |     625001.17 |  2072890.30 |       5568.5 |      2275.5 |    12
#    26 |          1.40 |        0.51 |       5774.9 |       472.7 |     5
#    27 |          1.27 |        0.99 |       5571.4 |      1813.7 |     8
#    28 |          3.02 |        0.00 |       6397.4 |         0.0 |     1
#    29 |          1.00 |        0.35 |       5985.4 |      1200.3 |     6
#    30 |          1.29 |        0.51 |       5699.6 |      1751.2 |     4
#    31 |          1.22 |        0.24 |       6171.1 |       813.3 |     7
#    32 |          1.37 |        0.35 |       6507.0 |       854.3 |     6
#    33 |          0.71 |        0.45 |       4278.7 |      2529.1 |     7
#    34 |     843751.14 |  2232352.64 |       6306.4 |       981.7 |     8
#
# Flow Ratio Distribution:
# Low (<0.8): 479 (53.2%)
# Medium (0.8-1.2): 127 (14.1%)
# High (>1.2): 294 (32.7%)
#
# Correlation between flow ratio and waiting time: 0.166
#
# Analysis complete! Results saved to flow_ratio_analysis.png

# %%
before_vehicles = {}
for i in range(4):
    before_vehicles[i] = set(i+j for j in range(4))
print(before_vehicles)
# Out:
# Running cells with 'Python 3.11.9' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Administrator/AppData/Local/Microsoft/WindowsApps/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'
